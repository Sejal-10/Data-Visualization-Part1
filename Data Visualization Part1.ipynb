# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
# crete a figure and axis
fig, ax = plt.subplots()


x = [2,6,5,4,8,9,5,1,3,2,1,6,4,1,2,6,6,4,1,2,3,6,1,1,1]
y = [2,6,7,9,9,8,4,9,5,4,9,5,4,6,5,4,5,6,1,5,6,6,1,1,2]


ax.scatter(x,y)

# %%
import pandas as pd 
iris = pd.read_csv("C:/Users/Pooja/Downloads/Iris.csv",index_col= 0)
print(iris.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Scatter plot

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ax.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'])
ax.set_title('Iris Dataset')
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('SepalWidthCm')
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %% [markdown]
# # Line Chart

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
x= range(1,6)
y=np.random.randint(1,20,5)
plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x19f76ac2a30>,
#   <matplotlib.axis.YTick at 0x19f76ac2610>,
#   <matplotlib.axis.YTick at 0x19f76abf4f0>,
#   <matplotlib.axis.YTick at 0x19f76af0d30>,
#   <matplotlib.axis.YTick at 0x19f76af5280>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
x = [2,6,5,4,8,9,5,1,3,2,1,6,4,1,2,6,6,4,1,2,3,6,1,1,1]
y = [2,6,7,9,9,8,4,9,5,4,9,5,4,6,5,4,5,6,1,5,6,6,1,1,2]
plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x19f76b1b0d0>,
#   <matplotlib.axis.YTick at 0x19f76b12cd0>,
#   <matplotlib.axis.YTick at 0x19f76b0ad00>,
#   <matplotlib.axis.YTick at 0x19f76b68130>,
#   <matplotlib.axis.YTick at 0x19f76b68640>,
#   <matplotlib.axis.YTick at 0x19f76b68b50>,
#   <matplotlib.axis.YTick at 0x19f76b626d0>,
#   <matplotlib.axis.YTick at 0x19f76b44190>,
#   <matplotlib.axis.YTick at 0x19f76b68880>,
#   <matplotlib.axis.YTick at 0x19f76b6f130>,
#   <matplotlib.axis.YTick at 0x19f76b6f640>,
#   <matplotlib.axis.YTick at 0x19f76b6fb50>,
#   <matplotlib.axis.YTick at 0x19f76b740a0>,
#   <matplotlib.axis.YTick at 0x19f76b745b0>,
#   <matplotlib.axis.YTick at 0x19f76b74ac0>,
#   <matplotlib.axis.YTick at 0x19f76b6f880>,
#   <matplotlib.axis.YTick at 0x19f76b52cd0>,
#   <matplotlib.axis.YTick at 0x19f76b74700>,
#   <matplotlib.axis.YTick at 0x19f76b7a1c0>,
#   <matplotlib.axis.YTick at 0x19f76b7a6d0>,
#   <matplotlib.axis.YTick at 0x19f76b7abe0>,
#   <matplotlib.axis.YTick at 0x19f76b80130>,
#   <matplotlib.axis.YTick at 0x19f76b80640>,
#   <matplotlib.axis.YTick at 0x19f76b80b50>,
#   <matplotlib.axis.YTick at 0x19f76b7a910>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # DataFrame Example

# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.DataFrame({
    'name':['Lauren','Sejal','Arya','Harry','Mish'],
    'age':[9,8,6,4,8],
    'gender':['F','F','F','M','M'],
    'state':['goa','maharashtra','UP','Bihar','MP'],
    'num_children':[6,5,2,3,1],
    'num_pets':[2,2,3,1,6]
})

ax = plt.gca()
df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets',color='red',ax=ax)
# Out:
# <AxesSubplot:xlabel='name'>

# %%
# to get coloums as plot
columns=iris.columns.drop(['Species'])
#create x data
x_data = range (0, iris.shape[0])
# create figure and axis
fig,ax= plt.subplots()
#plot each column
for column in columns:
    ax.plot(x_data, iris[column] , label=column)
#set title and legend
ax.set_title('Iris Dataset')
             
ax.legend()

# %% [markdown]
# # Histogram

# %%
fig,ax = plt.subplots()
ax.hist(iris['SepalLengthCm'])
        
ax.set_title('iris')
 
ax.set_xlabel('SepalLengthCm')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Bar chart

# %%
import pandas as pd 
wine_reviews = pd.read_csv("C:/Users/Pooja/Downloads/winemag-data-130k-v2.csv",index_col= 0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
fig, ax = plt.subplots()
data = wine_reviews['points'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('wine_reviews') 
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
wine_reviews['points'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
wine_reviews.groupby('country').price.mean().sort_values(ascending=False)[:6].plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
import numpy as np
import matplotlib.pyplot as plt
objects = ('Python','Java','C++','R','Script')
y_pos= np.arange(len(objects))
performance=[9,8,2,3,7]
plt.bar(y_pos, performance ,width = 0.5, align='center',alpha=0.7,color=['g','b','r','b','r'])
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.xlabel("Programming language")
plt.title('Programming Language Usage')
# Out:
# Text(0.5, 1.0, 'Programming Language Usage')

# %%
# to print the values above the bar
import matplotlib.pyplot as plt

# Declaring the figure or the plot (y,x) or (width, height)
plt.figure(figsize=(12, 7))

# Categorical data: Country names
countries = ['USA', 'Brazil', 'Russia', 'Spain', 'UK', 'India']

# integer value interms of death counts
totalDeaths = [112596, 37312, 5971, 27136, 40597, 7449]

# Passing the parameters to the bar function, this is the main function which creates the bar plot
plt.bar(countries, totalDeaths, width=0.9, align='center', color='cyan', edgecolor = 'red')

# This is the location for the annotated text
i =1.0
j =2000
# Annotating the bar plot with the values (total death counts)
for i in range(len(countries)):
    plt.annotate(totalDeaths[i], (-0.1+ i, totalDeaths[i] + j))

# Creating legend of the bars in the plot
plt.legend(labels = ['Total Deaths'])

# Giving the title for the plot
plt.title('Bar plot representing the total deaths by top 6 countries due to coronavirus')

# Naming the x and y axis
plt.xlabel('Countries')
plt.ylabel('Deaths')

# Saving the plot as a 'png'
plt.savefig("BarPlot.png")

# Display the bar plot
plt.show()

# %% [markdown]
# # Horizontal Bar Chart

# %%
wine_reviews['points'].value_counts().sort_index().plot.barh()
# Out:
# <AxesSubplot:>

# %%
# Importing the matplotlib library
import matplotlib.pyplot as plt
# Declaring 
plt.figure(figsize=[14,10])

plt.barh(['USA','RUSSIA','BRAZIL','UK','SPAIN'], [2026493,710887,47658,288797,287399], label = 'Danger Zone', color= 'red') 
plt.barh(['INDIA','ITALY','PERU','GERMANY','IRAN'], [265958,23565,12548,26547,26589] , label = 'Safe Zone', color = 'green')
plt.legend()

plt.xlabel('Total Cases')
plt.ylabel('Countries')
plt.title('TopAffected Countries\n by conronaravirus')
plt.savefig('2BarPlot.png')
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender': ['M','F','M','M','F','M','F'],
    'state':['calirfornia','dc','california','dc','california','taxas','taxas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3],
})           
             
             
df.groupby(['state','gender']).size().unstack().plot(kind='bar', stacked = True)
# Out:
# <AxesSubplot:xlabel='state'>

# %%
import pandas as pd
from matplotlib import pyplot as plt
Data = {'Country':['USA','CANADA','GERMANY','UK','FRANCE'],
        'GDP_Per_Capita': [ 45000,42000,52000,49000,47000],
        'Income_Per_Capita': [ 4000,5000,7000,55000,60000],
        }
        
df=pd.DataFrame(Data)
df.plot(x ='Country', y=['GDP_Per_Capita', 'Income_Per_Capita'], kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=[15,10])

# Data to be plotted
totalDeath = [1113055,37312,5971,7473,33964]
totalRecovery = [773480,325602,230688,129095,166584]
activecases= [1139958,347973,23999,129630,34730]
country=['USA','BRAZIL','RUSSIA','INDIA','ITALY']


X= np.arange(len(totalDeath))


plt.bar(X, totalDeath, color = 'black',width =0.25)
plt.bar(X + 0.25, totalRecovery, color = 'g',width =0.25)
plt.bar(X + 0.5, activecases, color = 'b',width =0.25)
plt.legend(['Total Deaths', 'Total Recovery','Actice Cases'])

plt.xticks([i+0.25 for i in range(5)], country)

plt.xlabel('countries')
plt.ylabel('cases')


plt.savefig('4BarPlot.png')
            
plt.show()

# %% [markdown]
# # Pie Chart

# %%
# Data Frame Plotting
from pandas import DataFrame
import matplotlib.pyplot as plt

Data = {'Tasks': [300,500,700],
        'Task Type': ['Task Pending', 'Task Ongoing','Tasks Completed']
       }

df = DataFrame(Data)
df.set_index('Task Type' , inplace=True)




df.plot.pie(y='Tasks', figsize=(10,10), autopct= '%1.1f%%', startangle=90)
# Out:
# <AxesSubplot:ylabel='Tasks'>

# %%
import matplotlib.pyplot as plt
# if using a  Jupyter notebook, include:
# %matplotlib inline

labels = ['Civil','Elecrical','Mechinal','Chemical']
sizes = [15,30,45,10]

explode = (0.1 , 0.1 ,0.1,0.4)


fig, ax= plt.subplots()
ax.pie(sizes,
       explode=explode,
       autopct='%1.1f%%',
       shadow =True,
       startangle=90)
ax.axis('equal')
ax.set_title('Engineering Diciplines')
# Out:
# Text(0.5, 1.0, 'Engineering Diciplines')

# %% [markdown]
# # Subplots

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,1")
plt.subplot(2,2,2)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,2")
plt.subplot(2,2,3)

# s is the size of dot
plt.scatter(range(1,6), np.random.randint(1,20,5), s = 100 , color = 'r')
plt.title("2,2,3")
plt.subplot(2,2,4)
plt.plot(range(1,6), np.random.randint(1,20,5), marker = 'o', color ='g',linestyle='--')
plt.title("2,2,4")
# Out:
# Text(0.5, 1.0, '2,2,4')

# %%
plt.bar(range(1,6), np.random.randint(1,20,5), width=0.5)
plt.scatter(range(1,6), np.random.randint(1,20,5), s = 200, color ='r')
plt.plot(range(1,6), np.random.randint(1,20,5), marker = 'o', color='g' , linestyle = '--')
